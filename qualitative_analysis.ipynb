# %%
qual_file = '/Users/jnaiman/LMM_Figure_Parsing/resources/qualitative_coding/qualitative.csv'

# %%
import pandas as pd

# %%
df = pd.read_csv(qual_file)

# %%
df
# Out:
#   Figure Name Correct Number of Panels Plotting Style Mentioned  \
# 0  Picture100                        Y                        N
# 1  Picture103                        Y                        N
# 2  Picture104                        Y                        N
# 3  Picture112                        Y                        N
# 4  Picture117                        Y                        N
# 5   Picture12                        Y                        N
# 6  Picture139                        Y                        N
#
#   Correct Number of Lines/Bars (NM=not mentioned) Correct plot type  \
# 0                                          Y/NA/N             Y/N/Y
# 1                                               N                 Y
# 2                                               Y                 Y
# 3                                              NM                 Y
# 4                                     NA/NA/NA/NA           Y/Y/N/Y
# 5                                           NA/NM               Y/Y
# 6                                              NM                 Y
#
#   Linestyles correct y-axis tick labels correct x-axis tick labels correct  \
# 0            N/NA/NA                      N/N/N                      N/N/N
# 1                NaN                          Y                          Y
# 2                NaN                          Y                          Y
# 3                NaN                          Y                          Y
# 4        NA/NA/NA/NA                    Y/N/N/N                    N/N/N/N
# 5              NA/NA                        N/N                        N/N
# 6                NaN                          Y                          Y
#
#   x-axis label mentioned  \
# 0                  N/N/N
# 1                      Y
# 2                      Y
# 3                      Y
# 4                Y/Y/N/N
# 5                    N/N
# 6                      Y
#
#   y-axis label mentioned (M=mentioned, C=correct, NC=not correct)  \
# 0                                              N/N/N
# 1                                               M-NC
# 2                                               M-NC
# 3                                                  Y
# 4                                      M-NC/M-NC/N/N
# 5                                              NM/NM
# 6                                                 NM
#
#   Title mentioned/Title correct (M=mentioned, C=correct, NC=not correct)  \
# 0                                        NA/M-NC/M-C
# 1                                                M-C
# 2                                                NaN
# 3                                                  Y
# 4                                         NA/Y/NA/NA
# 5                                            M-NC/NA
# 6                                                M-C
#
#   color bar mentioned error bars mentioned (NA means no error bars)  \
# 0             NA/N/NA                                       NA/N/NA
# 1                 NaN                                             N
# 2                 NaN                                             Y
# 3                 NaN                                             N
# 4         NA/M-NC/N/N                                      N/N/NA/N
# 5               NA/NA                                          NA/N
# 6                 NaN                                             N
#
#   other hallucinations
# 0              0.0/1/1
# 1                    2
# 2                    0
# 3                    0
# 4            1.0/1/0/1
# 5              2.0/2.0
# 6                    1

# %%
qual = {
    'Correct Number of Panels':{'incorrect':0, 'correct':0, 'df label':"Correct Number of Panels"},
    'Correct Plot Type':{'incorrect':0, 'correct':0, 'df label':"Correct plot type"},
    'Correct Number of Lines/Bars':{'incorrect':0, 'correct':0, 'df label':"Correct Number of Lines/Bars (NM=not mentioned)"},
    'Correct title':{'incorrect':0, 'correct':0, 'df label':"Title mentioned/Title correct (M=mentioned, C=correct, NC=not correct)"},
    'Correct x-axis labels':{'incorrect':0, 'correct':0, 'df label':"x-axis label mentioned"},
    'Correct y-axis labels':{'incorrect':0, 'correct':0, 'df label':"y-axis label mentioned (M=mentioned, C=correct, NC=not correct)"},
    'Correct x-axis tick labels':{'incorrect':0, 'correct':0, 'df label':"x-axis tick labels correct"},
    'Correct y-axis tick labels':{'incorrect':0, 'correct':0, 'df label':"y-axis tick labels correct"},
    'Error bars mentioned (when present)':{'incorrect':0, 'correct':0, 'df label':"error bars mentioned (NA means no error bars)"},
       }

for k,v in qual.items():
    d = df[v['df label']].values
    for dd in d: # all values
        if '/' not in str(dd):
            if str(dd).strip()=='Y':
                v['correct'] += 1
            elif str(dd).strip()=='N':
                v['incorrect'] += 1
            elif str(dd).strip()=='NM': # not mentioned
                v['incorrect'] += 1
            elif str(dd).strip()=='M-NC': # mentioned, but not correct
                v['incorrect'] += 1
            elif str(dd).strip()=='M-C': # mentioned, and correct
                v['correct'] += 1
            else:
                print('other:', str(dd).strip())
        else: # has multi
            d2 = dd.split('/')
            for dd2 in d2:
                if str(dd2).strip()=='Y':
                    v['correct'] += 1
                elif str(dd2).strip()=='N':
                    v['incorrect'] += 1
                elif str(dd2).strip()=='NM': # not mentioned
                    v['incorrect'] += 1
                elif str(dd2).strip()=='M-NC': # mentioned but not correct
                    v['incorrect'] += 1
                elif str(dd2).strip()=='M-C': # mentioned and correct
                    v['correct'] += 1
                else:
                    print('other, 2:', str(dd2).strip())
                
    #import sys; sys.exit()
# Out:
# other, 2: NA
# other, 2: NA
# other, 2: NA
# other, 2: NA
# other, 2: NA
# other, 2: NA
# other, 2: NA
# other: nan
# other, 2: NA
# other, 2: NA
# other, 2: NA
# other, 2: NA
# other, 2: NA
# other, 2: NA
# other, 2: NA
# other, 2: NA

# %%
qual_per = {} # percent correct
for k,v in qual.items():
    qual_per[k] = v['correct']/(v['correct']+v['incorrect'])*100

# %%
qual_per
# Out:
# {'Correct Number of Panels': 100.0,
#  'Correct Plot Type': 84.61538461538461,
#  'Correct Number of Lines/Bars': 28.57142857142857,
#  'Correct title': 71.42857142857143,
#  'Correct x-axis labels': 46.15384615384615,
#  'Correct y-axis labels': 7.6923076923076925,
#  'Correct x-axis tick labels': 30.76923076923077,
#  'Correct y-axis tick labels': 38.46153846153847,
#  'Error bars mentioned (when present)': 11.11111111111111}

# %% [markdown]
# Also count hallucinations:

# %%
hallucinations = 0
#hall_per_page = []
for d in df['other hallucinations'].values:
    if '/' not in d:
        hallucinations += int(float(d))
    else:
        dd = d.split('/')
        for d2 in dd:
            hallucinations += int(float(d2))

print('Total number of hallucinations:', hallucinations)
# Out:
# Total number of hallucinations: 12
